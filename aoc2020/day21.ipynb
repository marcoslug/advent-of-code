# %% [markdown]
# ---
# # --- Day 21: Allergen Assessment ---
# ---

# %%
import numpy as np

# %% [markdown]
# ### Input

# %%
with open("data/21_input.txt") as f:
    data = [l.strip() for l in f.readlines()]

# %%
def interpret_data(data):
    ingredients = {}
    allergens = {}
    list_all_ingredients = []
    for l in data:
        parts = l.split(" (contains ")
        list_allergens = parts[1][:-1].split(", ")
        list_ingredients = parts[0].split(" ")
        list_all_ingredients += list_ingredients
        for a in list_allergens:
            if a not in allergens:
                allergens[a] = set(list_ingredients)
            else:
                allergens[a] = allergens[a].intersection(set(list_ingredients))
        for i in list_ingredients:
            if i not in ingredients:
                ingredients[i] = set(list_allergens)
            else:
                ingredients[i] = ingredients[i].union(set(list_allergens))
    return ingredients, allergens, list_all_ingredients

# %%
ingredients, allergens, list_all_ingredients = interpret_data(data)

# %%
ingredients
# Out:
# {'xfvxzl': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'nfcrh': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'kscdhn': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'khnqq': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'jkvcbf': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'jhlvrg': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'chc': {'dairy', 'fish', 'nuts', 'peanuts', 'sesame', 'shellfish', 'soy'},
#  'fk': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'zbh': {'nuts', 'peanuts', 'sesame', 'shellfish', 'soy'},
#  'hgrptqb': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'zrvtg': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'tdhv': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'jhqpdf': {'dairy', 'fish', 'nuts', 'sesame', 'shellfish', 'soy', 'wheat'},
#  'jvjhx': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'rrmlg': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'mxsklfx': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'vzn': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'tmp': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'hrhg': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'fpcstf': {'dairy', 'fish', 'nuts', 'sesame', 'shellfish', 'soy', 'wheat'},
#  'zgpv': {'dairy', 'fish', 'sesame', 'shellfish', 'soy', 'wheat'},
#  'pdpgm': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'cbsvx': {'fish', 'nuts', 'peanuts', 'sesame', 'shellfish', 'soy', 'wheat'},
#  'ttkn': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'bkmgx': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'xknj': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'bxfvt': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'bdccss': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'tqjg': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'mkpmkx': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'fhpm': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'kcgtlb': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'ktrkfn': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'schkf': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'gcbbnqb': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'sfb': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'rjnx': {'dairy', 'fish', 'nuts', 'peanuts', 'sesame', 'shellfish', 'soy'},
#  'hcms': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'cjt': {'dairy', 'fish', 'nuts', 'sesame', 'shellfish', 'soy', 'wheat'},
#  'qhhsj': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'qddlrq': {'dairy', 'nuts', 'peanuts', 'sesame', 'shellfish', 'soy', 'wheat'},
#  'flnhl': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'vxzpfp': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'tplrt': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'bnl': {'dairy', 'fish', 'nuts', 'sesame', 'shellfish', 'soy', 'wheat'},
#  'ddmg': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'mxbbst': {'dairy', 'nuts', 'peanuts', 'sesame', 'shellfish', 'soy', 'wheat'},
#  'shlg': {'dairy', 'fish', 'nuts', 'peanuts', 'shellfish', 'soy', 'wheat'},
#  'ghq': {'fish', 'nuts', 'peanuts', 'sesame', 'shellfish', 'soy', 'wheat'},
#  'ppqs': {'fish', 'nuts', 'peanuts', 'sesame', 'shellfish', 'soy', 'wheat'},
#  'mqlnbjq': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'cltpv': {'dairy', 'fish', 'nuts', 'peanuts', 'shellfish', 'soy', 'wheat'},
#  'pvxpgp': {'dairy', 'fish', 'nuts', 'peanuts', 'sesame', 'shellfish', 'soy'},
#  'psbnqz': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'nqcmm': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'sqjcsxjq': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'xftxgfj': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'glxxp': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'fczfjr': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'phsr': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'dccscx': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'mxlzjfr': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'skrrb': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'rzlkxt': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'rdrzjqh': {'fish', 'nuts', 'peanuts', 'sesame', 'shellfish', 'soy', 'wheat'},
#  'vjbgmpr': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'tfgf': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'pvx': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'jbcjk': {'dairy', 'fish', 'nuts', 'peanuts', 'shellfish', 'soy', 'wheat'},
#  'pqnx': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'dlzpmb': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'sbhdb': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'szdxjlb': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'ljpzx': {'dairy', 'fish', 'nuts', 'peanuts', 'sesame', 'shellfish', 'soy'},
#  'kvrtf': {'dairy', 'fish', 'nuts', 'peanuts', 'shellfish', 'soy', 'wheat'},
#  'ccvzk': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'fjsq': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'xflfx': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'qgs': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'gcsjjf': {'dairy', 'fish', 'nuts', 'peanuts', 'sesame', 'shellfish', 'soy'},
#  'xfpc': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'gkfzqvc': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'cdslv': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'rzlbs': {'dairy', 'fish', 'nuts', 'peanuts', 'shellfish', 'soy', 'wheat'},
#  'tzrp': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'phfmh': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'kbgx': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'brdx': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'qtgv': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'msrnhf': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'cbhfpzp': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'dhqbf': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'fzhmtds': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'zbclt': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'pbln': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'xqcb': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'nnst': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'hzmvzrr': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'gkddl': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'dqz': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'kgrld': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'mdqlbx': {'dairy', 'fish', 'nuts', 'peanuts', 'sesame', 'shellfish'},
#  'nv': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'lsngc': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'ftkfc': {'dairy', 'fish', 'nuts', 'peanuts', 'sesame', 'shellfish', 'soy'},
#  'njtfs': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'tlgchbh': {'dairy', 'fish', 'nuts', 'sesame', 'shellfish', 'soy', 'wheat'},
#  'xhb': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'vbvfr': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'qrnxd': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'djldkx': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'kkcm': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'lvdcdg': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'strd': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'vtdbl': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'xknh': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'hctgkpd': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'vfqh': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'bxlc': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'nsktq': {'dairy', 'nuts', 'peanuts', 'sesame', 'shellfish', 'soy', 'wheat'},
#  'hrjrm': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'dbr': {'dairy', 'nuts', 'peanuts', 'sesame', 'soy'},
#  'prrfm': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'dbqbv': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'nfsrv': {'dairy', 'nuts', 'peanuts', 'sesame', 'soy', 'wheat'},
#  'lfmng': {'dairy', 'fish', 'nuts', 'sesame', 'shellfish', 'soy', 'wheat'},
#  'fhznhmx': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'rmxzzf': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'ghzx': {'dairy', 'fish', 'nuts', 'peanuts', 'shellfish', 'soy', 'wheat'},
#  'dzqs': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'gbplfj': {'dairy', 'nuts', 'peanuts', 'shellfish', 'soy'},
#  'dvzqx': {'dairy', 'nuts', 'peanuts', 'sesame', 'shellfish', 'soy', 'wheat'},
#  'vxpbn': {'nuts', 'peanuts', 'sesame', 'shellfish', 'soy', 'wheat'},
#  'jrpx': {'dairy', 'fish', 'nuts', 'peanuts', 'shellfish', 'soy', 'wheat'},
#  'sfpc': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'cpp': {'dairy', 'fish', 'nuts', 'peanuts', 'shellfish', 'soy', 'wheat'},
#  'gmtkh': {'dairy', 'fish', 'nuts', 'peanuts', 'sesame', 'shellfish', 'wheat'},
#  'txr': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'xsnrd': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'cmqrqcf': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'nhjbd': {'dairy', 'fish', 'nuts', 'peanuts', 'sesame', 'shellfish', 'soy'},
#  'jgpgql': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'dpkkzdgs': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'cjds': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'bbbzcmh': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'xkqgc': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'ktfvb': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'ntq': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'pcnmbt': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'ckpjgb': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'tgcvz': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'frv': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'mmdfrfcp': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'bkhjxl': {'dairy', 'fish', 'nuts', 'sesame', 'shellfish', 'soy'},
#  'cjdnjf': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'lgtvqf': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'cljvdxp': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'gkgzn': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'frgm': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'znkr': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'lnmv': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'ksrh': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'ssbldv': {'dairy', 'fish', 'nuts', 'sesame', 'shellfish', 'soy'},
#  'dpdgc': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'flmssjn': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'gpp': {'dairy', 'fish', 'peanuts', 'sesame', 'shellfish', 'soy', 'wheat'},
#  'jbvrzn': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'tjj': {'fish', 'nuts', 'peanuts', 'sesame', 'shellfish', 'soy', 'wheat'},
#  'qqbfj': {'dairy', 'nuts', 'peanuts', 'sesame', 'shellfish', 'soy', 'wheat'},
#  'tdsvx': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'jsdgn': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'vnxgpb': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'xttdqc': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'khnm': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'hzpsn': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'zhpv': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'cfbgb': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'bndz': {'dairy', 'fish', 'nuts', 'peanuts', 'sesame', 'shellfish', 'soy'},
#  'qqlm': {'dairy', 'fish', 'nuts', 'peanuts', 'sesame', 'shellfish', 'soy'},
#  'kpxcvj': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'jrj': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'hhvh': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'pvrhpt': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'qqmjlr': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'dqxjx': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'gnfjcpc': {'dairy', 'fish', 'nuts', 'peanuts', 'sesame', 'shellfish', 'soy'},
#  'tpbtpd': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'pgnk': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'xbksdv': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'dqrvvk': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'dnbhhv': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'drgdhp': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'xssjz': {'fish', 'nuts', 'peanuts', 'sesame', 'shellfish', 'soy', 'wheat'},
#  'spclmfb': {'dairy', 'fish', 'nuts', 'peanuts', 'sesame', 'shellfish', 'soy'},
#  'gcbz': {'dairy', 'nuts', 'peanuts', 'sesame', 'shellfish', 'soy', 'wheat'},
#  'lffhf': {'dairy',
#   'fish',
#   'nuts',
#   'peanuts',
#   'sesame',
#   'shellfish',
#   'soy',
#   'wheat'},
#  'ldggb': {'dairy', 'fish', 'nuts', 'peanuts', 'shellfish', 'soy', 'wheat'},
#  'ncqd': {'dairy', 'nuts', 'peanuts', 'sesame', 'shellfish', 'soy', 'wheat'},
#  'mpc': {'dairy', 'fish', 'peanuts', 'sesame', 'shellfish', 'soy', 'wheat'},
#  'gpqdxvv': {'dairy', 'fish', 'nuts', 'sesame', 'shellfish', 'soy', 'wheat'}}

# %%
allergens
# Out:
# {'shellfish': {'flnhl', 'mkpmkx'},
#  'sesame': {'ttkn'},
#  'fish': {'mkpmkx', 'pdpgm', 'ttkn'},
#  'nuts': {'cdslv', 'tmp'},
#  'dairy': {'tmp', 'ttkn'},
#  'soy': {'pdpgm', 'tmp', 'ttkn', 'vxzpfp'},
#  'wheat': {'cdslv', 'flnhl', 'ttkn'},
#  'peanuts': {'cdslv', 'tmp', 'zrvtg'}}

# %% [markdown]
# ### Part 1: associate allergens - ingredients

# %%
def resolve_combinations(dict_allergens, dict_ingredients):
    final_ingredients = dict_ingredients.copy()
    final_allergens = dict_allergens.copy()
    new_single = {}
    continuing = True
    while continuing:
        old_single = new_single
        new_single = {k:v for k, v in final_allergens.items() if len(v)==1}
        delta_single = {k:v for k, v in new_single.items() if k not in old_single.keys()}
        if (len(delta_single) == 0) and (len(new_single) == len(final_allergens)):
            print("Association completed!")
            continuing = False
        elif (len(delta_single) == 0) and (len(new_single) < len(final_allergens)):
            print("Impossible to continue.")
            continuing = False
        else:
            for a in delta_single.keys():
                for fa in final_allergens.keys():
                    if fa != a:
                        final_allergens[fa] = final_allergens[fa].difference(delta_single[a])
    # clean ingredients list
    for k, ass in new_single.items():
        for i, v in final_ingredients.items():
            if i != list(ass)[0]:
                final_ingredients[i] = v.difference({k})
    return final_allergens, final_ingredients

# %%
final_allergens, final_ingredients = resolve_combinations(allergens, ingredients)
# Out:
# Association completed!

# %%
final_allergens
# Out:
# {'shellfish': {'mkpmkx'},
#  'sesame': {'ttkn'},
#  'fish': {'pdpgm'},
#  'nuts': {'cdslv'},
#  'dairy': {'tmp'},
#  'soy': {'vxzpfp'},
#  'wheat': {'flnhl'},
#  'peanuts': {'zrvtg'}}

# %%
allergen_free_ingredients = [k for k, v in final_ingredients.items() if len(v)==0]

# %%
len([i for i in list_all_ingredients if i in allergen_free_ingredients])
# Out:
# 2410

# %% [markdown]
# ### Part 2: canonical dangerous ingredient list

# %%
final_allergens
# Out:
# {'shellfish': {'mkpmkx'},
#  'sesame': {'ttkn'},
#  'fish': {'pdpgm'},
#  'nuts': {'cdslv'},
#  'dairy': {'tmp'},
#  'soy': {'vxzpfp'},
#  'wheat': {'flnhl'},
#  'peanuts': {'zrvtg'}}

# %%
allergen_list = list(final_allergens.keys())
allergen_list.sort()

# %%
cdi = ",".join([list(final_allergens[a])[0] for a in allergen_list])

# %%
cdi
# Out:
# 'tmp,pdpgm,cdslv,zrvtg,ttkn,mkpmkx,vxzpfp,flnhl'
