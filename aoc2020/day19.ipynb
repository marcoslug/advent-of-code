# %% [markdown]
# ---
# # --- Day 19: Monster Messages ---
# ---

# %%
import numpy as np
import itertools

# %% [markdown]
# ### Input

# %%
with open("data/19_input.txt") as f:
    data = [l.strip() for l in f.readlines()]
with open("data/19_input_test.txt") as f:
    data_test = [l.strip() for l in f.readlines()]

# %%
def interpret_data(data):
    rules = {}
    rules_to_fill = {}
    for i, l in enumerate(data):
        if l == "":
            break
        parts = l.split(": ")
        k = int(parts[0])
        if parts[1][0] == '"':
            rules[k] = set([str(parts[1][1:-1])])
        else:
            rules_to_fill[k] = [[int(n) for n in p.split(" ")] for p in parts[1].split(" | ")]
    messages = data[i+1:]
    return rules, rules_to_fill, messages

# %%
rules, rules_to_fill, messages = interpret_data(data)

# %% [markdown]
# ### Part 1: fill rules

# %%
def fill_rules(rules, rules_to_fill):
    complete_rules = rules.copy()
    rules_to_fill_int = rules_to_fill.copy()
    available_rules = set(complete_rules.keys())
    print(f"Number of available rules: {len(available_rules)}.")
    print(f"Number of rules still to fill: {len(rules_to_fill)}.")
    while (len(rules_to_fill_int) > 0):
        fillable_rules = [key for key, rule in rules_to_fill_int.items() if len(set([el for comb in rule for el in comb]).difference(available_rules)) == 0]
        if len(fillable_rules) == 0:
            print("Impossible to continue!")
            break
        else:
            for rid in fillable_rules:
                new_rule = [["".join(p) for p in list(itertools.product(*[complete_rules[i] for i in comb]))] for comb in rules_to_fill_int[rid]]
                complete_rules[rid] = set([el for comb in new_rule for el in comb])
                del rules_to_fill_int[rid]
            available_rules = available_rules.union(set(fillable_rules))
            print(f"Number of available rules: {len(available_rules)}.")
            print(f"Number of rules still to fill: {len(rules_to_fill_int)}.")            
    
    return complete_rules, rules_to_fill_int

# %%
complete_rules = fill_rules(rules, rules_to_fill)[0]
# Out:
# Number of available rules: 2.
# Number of rules still to fill: 127.
# Number of available rules: 12.
# Number of rules still to fill: 117.
# Number of available rules: 41.
# Number of rules still to fill: 88.
# Number of available rules: 75.
# Number of rules still to fill: 54.
# Number of available rules: 97.
# Number of rules still to fill: 32.
# Number of available rules: 112.
# Number of rules still to fill: 17.
# Number of available rules: 120.
# Number of rules still to fill: 9.
# Number of available rules: 124.
# Number of rules still to fill: 5.
# Number of available rules: 126.
# Number of rules still to fill: 3.
# Number of available rules: 128.
# Number of rules still to fill: 1.
# Number of available rules: 129.
# Number of rules still to fill: 0.

# %%
complete_rules[0]
# Out:
# {'aabbbababaaabbaababaabba',
#  'abaababbbbabbababbbbbbaa',
#  'ababbabbbbabaaabababaaaa',
#  'aaaabababbbbbaaabaaaabaa',
#  'abbbbabbbbbabbbbbaaaaaba',
#  'ababbbaaaabaabaabbbbaaaa',
#  'aabababaaaaaaaababaabaaa',
#  'aabbbbbaaabbbababbbbbbba',
#  'babaaaaabbbbbaaaaabbabba',
#  'baaaaaabaabbbaabaaaababb',
#  'abbbabbabbbaabaabaaaabab',
#  'babbaabbaabbababbbbababa',
#  'abbaaabaaabbaababbaababa',
#  'aaabbbbbbaaabaabaabbaaab',
#  'bbabaaabaabbbbabaaabbbaa',
#  'babbabababaabbbbabbabbab',
#  'aababbbbbaaaaaabbabbaaaa',
#  'babbaababbabbbbbabbbaaba',
#  'bbababbbababbabbbaaababa',
#  'abbababbaabbababbbbbaaba',
#  'bbababbabaaababbaabbaabb',
#  'aabbbbbbbbbbbaabaabbaaab',
#  'bbbbbaaaabbbbaaaaaaaaaaa',
#  'baaaaaabbbbaaaababbbbbaa',
#  'bbaababbababaabbbababaab',
#  'abaaababbabaaababaabaabb',
#  'aababbaabaaabbababaaaaab',
#  'bbabaaabaabaabbbbbabbbba',
#  'baabbaabaaaaabbbaaaabbab',
#  'bababbaaabaabbabbbaaaaab',
#  'baaaaabbbbbbabbbbbabbaab',
#  'bbababbbbbaaaabaababbbba',
#  'aabaabbaaabbabababbbbbaa',
#  'abbaabbababbabaaaabbaaab',
#  'babababaaabbbbbabaababab',
#  'aabbbbababbaaabbbbbaabbb',
#  'baabbababbabbbbbbaaaaaba',
#  'aabbbababbbbaabbabbbbbaa',
#  'baabbbbbbaabaababaaaaaaa',
#  'bbaababbabaaaaaabbbbbbaa',
#  'abbbbabbaaabbbbabbaababa',
#  'bbabaabaababbbbbbabbabba',
#  'baabaaaaaaababbabaaabaaa',
#  'aabbbbbbabababbaababbaaa',
#  'bbbaaaaaaabbbaababbbbaab',
#  'bbaaaabaabbbbabbbbbbbbaa',
#  'aababbbabbaaababbbbabaab',
#  'aaaaaababbabbabaaababaaa',
#  ...}

# %%
sum([m in complete_rules[0] for m in messages])
# Out:
# 205

# %% [markdown]
# ### Part 2: changes of rules 8 and 11

# %%
rules_to_fill[8] = [[42], [42, 8]]
rules_to_fill[11] = [[42, 31], [42,11,31]]

# %%
partial_rules, remaining_rules = fill_rules(rules, rules_to_fill)
# Out:
# Number of available rules: 2.
# Number of rules still to fill: 127.
# Number of available rules: 12.
# Number of rules still to fill: 117.
# Number of available rules: 41.
# Number of rules still to fill: 88.
# Number of available rules: 75.
# Number of rules still to fill: 54.
# Number of available rules: 97.
# Number of rules still to fill: 32.
# Number of available rules: 112.
# Number of rules still to fill: 17.
# Number of available rules: 120.
# Number of rules still to fill: 9.
# Number of available rules: 124.
# Number of rules still to fill: 5.
# Number of available rules: 126.
# Number of rules still to fill: 3.
# Impossible to continue!

# %%
remaining_rules
# Out:
# {8: [[42], [42, 8]], 0: [[8, 11]], 11: [[42, 31], [42, 11, 31]]}

# %%
{len(d) for d in partial_rules[42]}
# Out:
# {8}

# %%
{len(d) for d in partial_rules[31]}
# Out:
# {8}

# %%
{len(m) for m in messages}
# Out:
# {24, 32, 40, 48, 56, 64, 72, 80, 88}

# %%
def get_matching_messages(messages, rule42, rule31, msglength=8):
    good_messages = []
    for j, m in enumerate(messages):
        print(f"Checking message {j+1}...", end=" ")
        len_head = int(np.floor(len(m)/msglength/2+1))*msglength
        all_head_matching_42 = np.all([part in rule42 for part in [m[i:i+msglength] for i in range(0,len_head,msglength)]])
        still_good = all_head_matching_42 and (m[-msglength:] in rule31)
        if still_good and False:
            middle = m[len_head:-msglength]
            i = 0
            change = False
            while still_good and (i < len(middle)):
                bite = middle[i:i+msglength]
                if not change:
                    if bite in rule42:
                        pass
                    elif bite in rule31:
                        change = True
                    else:
                        still_good = False
                if change:
                    if bite in rule31:
                        still_good = True
                    else:
                        still_good = False
                i += msglength
        if still_good:
            print("added.")
            good_messages.append(m)
        else:
            print("not added.")
    return good_messages

# %%
good_messages =  get_matching_messages(messages, partial_rules[42], partial_rules[31])
# Out:
# Checking message 1... added.
# Checking message 2... not added.
# Checking message 3... not added.
# Checking message 4... added.
# Checking message 5... not added.
# Checking message 6... added.
# Checking message 7... not added.
# Checking message 8... added.
# Checking message 9... added.
# Checking message 10... not added.
# Checking message 11... not added.
# Checking message 12... added.
# Checking message 13... added.
# Checking message 14... added.
# Checking message 15... added.
# Checking message 16... added.
# Checking message 17... added.
# Checking message 18... added.
# Checking message 19... not added.
# Checking message 20... not added.
# Checking message 21... added.
# Checking message 22... added.
# Checking message 23... not added.
# Checking message 24... not added.
# Checking message 25... not added.
# Checking message 26... added.
# Checking message 27... added.
# Checking message 28... added.
# Checking message 29... not added.
# Checking message 30... added.
# Checking message 31... added.
# Checking message 32... not added.
# Checking message 33... added.
# Checking message 34... added.
# Checking message 35... not added.
# Checking message 36... not added.
# Checking message 37... not added.
# Checking message 38... added.
# Checking message 39... added.
# Checking message 40... added.
# Checking message 41... added.
# Checking message 42... added.
# Checking message 43... not added.
# Checking message 44... added.
# Checking message 45... not added.
# Checking message 46... added.
# Checking message 47... added.
# Checking message 48... added.
# Checking message 49... added.
# Checking message 50... added.
# Checking message 51... added.
# Checking message 52... added.
# Checking message 53... added.
# Checking message 54... added.
# Checking message 55... added.
# Checking message 56... added.
# Checking message 57... added.
# Checking message 58... added.
# Checking message 59... added.
# Checking message 60... added.
# Checking message 61... added.
# Checking message 62... added.
# Checking message 63... not added.
# Checking message 64... not added.
# Checking message 65... added.
# Checking message 66... not added.
# Checking message 67... added.
# Checking message 68... added.
# Checking message 69... not added.
# Checking message 70... added.
# Checking message 71... added.
# Checking message 72... added.
# Checking message 73... not added.
# Checking message 74... not added.
# Checking message 75... not added.
# Checking message 76... added.
# Checking message 77... added.
# Checking message 78... added.
# Checking message 79... added.
# Checking message 80... added.
# Checking message 81... added.
# Checking message 82... not added.
# Checking message 83... added.
# Checking message 84... added.
# Checking message 85... added.
# Checking message 86... added.
# Checking message 87... added.
# Checking message 88... not added.
# Checking message 89... added.
# Checking message 90... added.
# Checking message 91... not added.
# Checking message 92... added.
# Checking message 93... not added.
# Checking message 94... added.
# Checking message 95... added.
# Checking message 96... added.
# Checking message 97... added.
# Checking message 98... added.
# Checking message 99... not added.
# Checking message 100... added.
# Checking message 101... added.
# Checking message 102... not added.
# Checking message 103... added.
# Checking message 104... added.
# Checking message 105... added.
# Checking message 106... added.
# Checking message 107... not added.
# Checking message 108... added.
# Checking message 109... not added.
# Checking message 110... added.
# Checking message 111... not added.
# Checking message 112... added.
# Checking message 113... added.
# Checking message 114... added.
# Checking message 115... not added.
# Checking message 116... added.
# Checking message 117... added.
# Checking message 118... added.
# Checking message 119... not added.
# Checking message 120... added.
# Checking message 121... added.
# Checking message 122... added.
# Checking message 123... added.
# Checking message 124... not added.
# Checking message 125... added.
# Checking message 126... added.
# Checking message 127... added.
# Checking message 128... added.
# Checking message 129... added.
# Checking message 130... not added.
# Checking message 131... not added.
# Checking message 132... not added.
# Checking message 133... added.
# Checking message 134... not added.
# Checking message 135... not added.
# Checking message 136... added.
# Checking message 137... added.
# Checking message 138... added.
# Checking message 139... added.
# Checking message 140... added.
# Checking message 141... added.
# Checking message 142... added.
# Checking message 143... added.
# Checking message 144... not added.
# Checking message 145... added.
# Checking message 146... added.
# Checking message 147... added.
# Checking message 148... added.
# Checking message 149... added.
# Checking message 150... added.
# Checking message 151... added.
# Checking message 152... added.
# Checking message 153... added.
# Checking message 154... not added.
# Checking message 155... not added.
# Checking message 156... added.
# Checking message 157... added.
# Checking message 158... added.
# Checking message 159... added.
# Checking message 160... added.
# Checking message 161... not added.
# Checking message 162... added.
# Checking message 163... not added.
# Checking message 164... not added.
# Checking message 165... added.
# Checking message 166... added.
# Checking message 167... added.
# Checking message 168... added.
# Checking message 169... not added.
# Checking message 170... not added.
# Checking message 171... not added.
# Checking message 172... not added.
# Checking message 173... not added.
# Checking message 174... added.
# Checking message 175... added.
# Checking message 176... not added.
# Checking message 177... added.
# Checking message 178... added.
# Checking message 179... added.
# Checking message 180... added.
# Checking message 181... not added.
# Checking message 182... added.
# Checking message 183... added.
# Checking message 184... added.
# Checking message 185... not added.
# Checking message 186... added.
# Checking message 187... added.
# Checking message 188... not added.
# Checking message 189... added.
# Checking message 190... added.
# Checking message 191... added.
# Checking message 192... added.
# Checking message 193... added.
# Checking message 194... added.
# Checking message 195... not added.
# Checking message 196... added.
# Checking message 197... added.
# Checking message 198... added.
# Checking message 199... not added.
# Checking message 200... added.
# Checking message 201... added.
# Checking message 202... added.
# Checking message 203... not added.
# Checking message 204... not added.
# Checking message 205... added.
# Checking message 206... added.
# Checking message 207... added.
# Checking message 208... added.
# Checking message 209... added.
# Checking message 210... added.
# Checking message 211... added.
# Checking message 212... added.
# Checking message 213... not added.
# Checking message 214... added.
# Checking message 215... added.
# Checking message 216... not added.
# Checking message 217... added.
# Checking message 218... not added.
# Checking message 219... added.
# Checking message 220... added.
# Checking message 221... added.
# Checking message 222... added.
# Checking message 223... added.
# Checking message 224... added.
# Checking message 225... added.
# Checking message 226... added.
# Checking message 227... added.
# Checking message 228... added.
# Checking message 229... added.
# Checking message 230... added.
# Checking message 231... added.
# Checking message 232... added.
# Checking message 233... added.
# Checking message 234... not added.
# Checking message 235... added.
# Checking message 236... added.
# Checking message 237... added.
# Checking message 238... added.
# Checking message 239... added.
# Checking message 240... added.
# Checking message 241... added.
# Checking message 242... added.
# Checking message 243... not added.
# Checking message 244... added.
# Checking message 245... not added.
# Checking message 246... not added.
# Checking message 247... added.
# Checking message 248... added.
# Checking message 249... added.
# Checking message 250... added.
# Checking message 251... added.
# Checking message 252... not added.
# Checking message 253... added.
# Checking message 254... added.
# Checking message 255... added.
# Checking message 256... added.
# Checking message 257... added.
# Checking message 258... added.
# Checking message 259... added.
# Checking message 260... added.
# Checking message 261... added.
# Checking message 262... added.
# Checking message 263... added.
# Checking message 264... added.
# Checking message 265... added.
# Checking message 266... added.
# Checking message 267... not added.
# Checking message 268... added.
# Checking message 269... added.
# Checking message 270... added.
# Checking message 271... added.
# Checking message 272... added.
# Checking message 273... added.
# Checking message 274... added.
# Checking message 275... added.
# Checking message 276... not added.
# Checking message 277... added.
# Checking message 278... added.
# Checking message 279... added.
# Checking message 280... not added.
# Checking message 281... added.
# Checking message 282... added.
# Checking message 283... added.
# Checking message 284... added.
# Checking message 285... added.
# Checking message 286... added.
# Checking message 287... added.
# Checking message 288... added.
# Checking message 289... added.
# Checking message 290... not added.
# Checking message 291... added.
# Checking message 292... added.
# Checking message 293... not added.
# Checking message 294... added.
# Checking message 295... added.
# Checking message 296... added.
# Checking message 297... not added.
# Checking message 298... added.
# Checking message 299... added.
# Checking message 300... not added.
# Checking message 301... added.
# Checking message 302... not added.
# Checking message 303... added.
# Checking message 304... added.
# Checking message 305... added.
# Checking message 306... added.
# Checking message 307... added.
# Checking message 308... added.
# Checking message 309... added.
# Checking message 310... added.
# Checking message 311... added.
# Checking message 312... added.
# Checking message 313... not added.
# Checking message 314... added.
# Checking message 315... added.
# Checking message 316... added.
# Checking message 317... not added.
# Checking message 318... added.
# Checking message 319... added.
# Checking message 320... added.
# Checking message 321... added.
# Checking message 322... added.
# Checking message 323... not added.
# Checking message 324... not added.
# Checking message 325... added.
# Checking message 326... not added.
# Checking message 327... not added.
# Checking message 328... not added.
# Checking message 329... added.
# Checking message 330... added.
# Checking message 331... added.
# Checking message 332... added.
# Checking message 333... added.
# Checking message 334... added.
# Checking message 335... added.
# Checking message 336... not added.
# Checking message 337... not added.
# Checking message 338... added.
# Checking message 339... not added.
# Checking message 340... added.
# Checking message 341... added.
# Checking message 342... added.
# Checking message 343... added.
# Checking message 344... not added.
# Checking message 345... added.
# Checking message 346... not added.
# Checking message 347... added.
# Checking message 348... added.
# Checking message 349... not added.
# Checking message 350... added.
# Checking message 351... not added.
# Checking message 352... added.
# Checking message 353... added.
# Checking message 354... added.
# Checking message 355... added.
# Checking message 356... added.
# Checking message 357... added.
# Checking message 358... added.
# Checking message 359... added.
# Checking message 360... not added.
# Checking message 361... added.
# Checking message 362... added.
# Checking message 363... added.
# Checking message 364... not added.
# Checking message 365... added.
# Checking message 366... added.
# Checking message 367... added.
# Checking message 368... not added.
# Checking message 369... added.
# Checking message 370... added.
# Checking message 371... added.
# Checking message 372... added.
# Checking message 373... added.
# Checking message 374... not added.
# Checking message 375... not added.
# Checking message 376... added.
# Checking message 377... added.
# Checking message 378... not added.
# Checking message 379... added.
# Checking message 380... added.
# Checking message 381... added.
# Checking message 382... added.
# Checking message 383... added.
# Checking message 384... added.
# Checking message 385... added.
# Checking message 386... added.
# Checking message 387... added.
# Checking message 388... added.
# Checking message 389... added.
# Checking message 390... not added.
# Checking message 391... added.
# Checking message 392... added.
# Checking message 393... not added.
# Checking message 394... added.
# Checking message 395... added.
# Checking message 396... added.
# Checking message 397... added.
# Checking message 398... added.
# Checking message 399... added.
# Checking message 400... not added.
# Checking message 401... added.
# Checking message 402... added.
# Checking message 403... added.
# Checking message 404... added.
# Checking message 405... added.
# Checking message 406... added.
# Checking message 407... added.
# Checking message 408... added.
# Checking message 409... not added.
# Checking message 410... added.
# Checking message 411... not added.
# Checking message 412... not added.
# Checking message 413... added.
# Checking message 414... added.
# Checking message 415... added.
# Checking message 416... added.
# Checking message 417... added.
# Checking message 418... added.
# Checking message 419... added.
# Checking message 420... added.
# Checking message 421... added.
# Checking message 422... not added.
# Checking message 423... added.
# Checking message 424... added.
# Checking message 425... added.
# Checking message 426... added.
# Checking message 427... added.
# Checking message 428... not added.
# Checking message 429... added.
# Checking message 430... added.
# Checking message 431... added.
# Checking message 432... added.
# Checking message 433... added.
# Checking message 434... added.

# %%
len(good_messages)
# Out:
# 329

# %% [markdown]
# ### Test

# %%
rules_t, rules_to_fill_t, messages_t = interpret_data(data_test)

# %%
complete_rules_t = fill_rules(rules_t, rules_to_fill_t)[0]
# Out:
# Number of available rules: 2.
# Number of rules still to fill: 29.
# Number of available rules: 10.
# Number of rules still to fill: 21.
# Number of available rules: 17.
# Number of rules still to fill: 14.
# Number of available rules: 22.
# Number of rules still to fill: 9.
# Number of available rules: 26.
# Number of rules still to fill: 5.
# Number of available rules: 28.
# Number of rules still to fill: 3.
# Number of available rules: 30.
# Number of rules still to fill: 1.
# Number of available rules: 31.
# Number of rules still to fill: 0.

# %%
sum([m in complete_rules_t[0] for m in messages_t])
# Out:
# 3

# %%
rules_to_fill_t[8] = [[42], [42, 8]]
rules_to_fill_t[11] = [[42, 31], [42,11,31]]

# %%
partial_rules_t, remaining_rules_t = fill_rules(rules_t, rules_to_fill_t)
# Out:
# Number of available rules: 2.
# Number of rules still to fill: 29.
# Number of available rules: 10.
# Number of rules still to fill: 21.
# Number of available rules: 17.
# Number of rules still to fill: 14.
# Number of available rules: 22.
# Number of rules still to fill: 9.
# Number of available rules: 26.
# Number of rules still to fill: 5.
# Number of available rules: 28.
# Number of rules still to fill: 3.
# Impossible to continue!

# %%
good_messages_t =  get_matching_messages(messages_t, partial_rules_t[42], partial_rules_t[31], msglength=5)
# Out:
# Checking message 1... not added.
# Checking message 2... added.
# Checking message 3... added.
# Checking message 4... added.
# Checking message 5... added.
# Checking message 6... added.
# Checking message 7... added.
# Checking message 8... added.
# Checking message 9... added.
# Checking message 10... added.
# Checking message 11... added.
# Checking message 12... not added.
# Checking message 13... added.
# Checking message 14... not added.
# Checking message 15... added.

# %%
len(good_messages_t)
# Out:
# 12
